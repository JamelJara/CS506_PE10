# %%
from keras.datasets import imdb
from keras import preprocessing

max_features = 10000
maxlen = 20

(x_train, y_train), (x_test, y_test) = imdb.load_data(num_words=max_features)

x_train = preprocessing.sequence.pad_sequences(x_train, maxlen=maxlen)
x_test = preprocessing.sequence.pad_sequences(x_test, maxlen=maxlen)
# Out:
# ...
# 17464789/17464789 [==============================] - 0s 0us/step

# %%
# Using sigmoid activation function

from keras.models import Sequential
from keras.layers import Flatten, Dense, Embedding

model = Sequential()
num_layer = 8
model.add(Embedding(max_features, num_layer, input_length=maxlen))
model.add(Flatten())
model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['acc'])

model.summary()

history = model.fit(x_train, y_train, epochs=10, batch_size=12, validation_data=(x_test, y_test))
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  embedding (Embedding)       (None, 20, 8)             80000
#
#  flatten (Flatten)           (None, 160)               0
#
#  dense (Dense)               (None, 1)                 161
#
# ...
# Total params: 80161 (313.13 KB)
# Trainable params: 80161 (313.13 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/10
# 2084/2084 [==============================] - 11s 5ms/step - loss: 0.6289 - acc: 0.6560 - val_loss: 0.5381 - val_acc: 0.7302
# Epoch 2/10
# 2084/2084 [==============================] - 10s 5ms/step - loss: 0.4874 - acc: 0.7644 - val_loss: 0.4947 - val_acc: 0.7568
# Epoch 3/10
# 2084/2084 [==============================] - 9s 4ms/step - loss: 0.4461 - acc: 0.7909 - val_loss: 0.4894 - val_acc: 0.7616
# Epoch 4/10
# ...

# %%
import matplotlib.pyplot as plt

acc = history.history['acc']
val_acc = history.history['val_acc']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(acc) + 1)

plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()

plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %%
from keras.datasets import imdb
from keras import preprocessing

max_freatures = 10000
maxlen = 60

(x_train, y_train), (x_test, y_test) = imdb.load_data(num_words=max_features)

x_train = preprocessing.sequence.pad_sequences(x_train, maxlen=maxlen)
x_test = preprocessing.sequence.pad_sequences(x_test, maxlen=maxlen)

# %%
# Using sigmoid & relu activation function

from keras.models import Sequential
from keras.layers import Flatten, Dense, Embedding

model = Sequential()
num_layer = 16

model.add(Embedding(max_features, num_layer, input_length=maxlen))
model.add(Flatten())
model.add(Dense(1, activation='sigmoid'))
model.add(Dense(32, activation='relu'))
model.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['acc'])

model.summary()
history = model.fit(x_train, y_train, epochs=10, batch_size=12, validation_data=(x_test, y_test))
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  embedding_1 (Embedding)     (None, 60, 16)            160000
#
#  flatten_1 (Flatten)         (None, 960)               0
#
#  dense_1 (Dense)             (None, 1)                 961
#
#  dense_2 (Dense)             (None, 32)                64
#
# ...
# Total params: 161025 (629.00 KB)
# Trainable params: 161025 (629.00 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/10
# 2084/2084 [==============================] - 13s 6ms/step - loss: 3.6875 - acc: 0.0000e+00 - val_loss: 3.6060 - val_acc: 0.0000e+00
# Epoch 2/10
# 2084/2084 [==============================] - 10s 5ms/step - loss: 3.5853 - acc: 0.0050 - val_loss: 3.5959 - val_acc: 0.0643
# Epoch 3/10
# ...

# %%
import matplotlib.pyplot as plt

acc = history.history['acc']
val_acc = history.history['val_acc']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(acc) + 1)

plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()

plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %%
from keras.datasets import imdb
from keras import preprocessing

max_features = 10000
maxlen = 100

(x_train, y_train), (x_test, y_test) = imdb.load_data(num_words=max_features)

x_train = preprocessing.sequence.pad_sequences(x_train, maxlen=maxlen)
x_test  = preprocessing.sequence.pad_sequences(x_test, maxlen=maxlen)

# %%
# Using sigmoid and Tanh activation function

from keras.models import Sequential
from keras.layers import Flatten, Dense, Embedding

model = Sequential()

num_layer = 64
model.add(Embedding(max_features, num_layer, input_length=maxlen))
model.add(Flatten())
model.add(Dense(1, activation='sigmoid'))
model.add(Dense(64, activation='tanh'))
model.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['acc'])
model.summary()
history = model.fit(x_train, y_train, epochs=10, batch_size=12, validation_data=(x_test, y_test))
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  embedding_2 (Embedding)     (None, 100, 64)           640000
#
#  flatten_2 (Flatten)         (None, 6400)              0
#
#  dense_3 (Dense)             (None, 1)                 6401
#
#  dense_4 (Dense)             (None, 64)                128
#
# ...
# Total params: 646529 (2.47 MB)
# Trainable params: 646529 (2.47 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/10
# 2084/2084 [==============================] - 17s 8ms/step - loss: 3.8352 - acc: 2.0000e-04 - val_loss: 3.7233 - val_acc: 0.0000e+00
# Epoch 2/10
# 2084/2084 [==============================] - 16s 8ms/step - loss: 3.6853 - acc: 0.0000e+00 - val_loss: 3.6858 - val_acc: 0.0000e+00
# Epoch 3/10
# ...

# %%
import matplotlib.pyplot as plt

acc = history.history['acc']
val_acc = history.history['val_acc']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(acc) + 1)

plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()

plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %%
from keras.datasets import imdb
from keras import preprocessing

max_features = 10000
maxlen = 140

(x_train, y_train), (x_test, y_test) = imdb.load_data(num_words=max_features)

x_train = preprocessing.sequence.pad_sequences(x_train, maxlen=maxlen)
x_test  = preprocessing.sequence.pad_sequences(x_test, maxlen=maxlen)

# %%
# Using sigmoid and linear activation function

from keras.models import Sequential
from keras.layers import Flatten, Dense, Embedding

model = Sequential()

num_layer = 128
model.add(Embedding(max_features, num_layer, input_length=maxlen))
model.add(Flatten())
model.add(Dense(1, activation='sigmoid'))
model.add(Dense(1, activation='linear'))
model.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['acc'])
model.summary()
history = model.fit(x_train, y_train, epochs=10, batch_size=12, validation_data=(x_test, y_test))
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  embedding_3 (Embedding)     (None, 140, 128)          1280000
#
#  flatten_3 (Flatten)         (None, 17920)             0
#
#  dense_5 (Dense)             (None, 1)                 17921
#
#  dense_6 (Dense)             (None, 1)                 2
#
# ...
# Total params: 1297923 (4.95 MB)
# Trainable params: 1297923 (4.95 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/10
# 2084/2084 [==============================] - 27s 12ms/step - loss: 7.7125 - acc: 0.5000 - val_loss: 7.7125 - val_acc: 0.5000
# Epoch 2/10
# 2084/2084 [==============================] - 24s 11ms/step - loss: 7.7125 - acc: 0.5000 - val_loss: 7.7125 - val_acc: 0.5000
# Epoch 3/10
# ...

# %%
import matplotlib.pyplot as plt

acc = history.history['acc']
val_acc = history.history['val_acc']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(acc) + 1)

plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()

plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %%
from keras.datasets import imdb
from keras import preprocessing

max_features = 10000
maxlen = 180

(x_train, y_train), (x_test, y_test) = imdb.load_data(num_words=max_features)

x_train = preprocessing.sequence.pad_sequences(x_train, maxlen=maxlen)
x_test  = preprocessing.sequence.pad_sequences(x_test, maxlen=maxlen)

# %%
# Using sigmoid, relu, and Tanh activation function

from keras.models import Sequential
from keras.layers import Flatten, Dense, Embedding

model = Sequential()

num_layer = 8
model.add(Embedding(max_features, num_layer, input_length=maxlen))
model.add(Flatten())
model.add(Dense(1, activation='sigmoid'))
model.add(Dense(32, activation='relu'))
model.add(Dense(64, activation='tanh'))
model.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['acc'])
model.summary()
history = model.fit(x_train, y_train, epochs=10, batch_size=12, validation_data=(x_test, y_test))
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  embedding_4 (Embedding)     (None, 180, 8)            80000
#
#  flatten_4 (Flatten)         (None, 1440)              0
#
#  dense_7 (Dense)             (None, 1)                 1441
#
#  dense_8 (Dense)             (None, 32)                64
#
#  dense_9 (Dense)             (None, 64)                2112
#
# ...
# Total params: 83617 (326.63 KB)
# Trainable params: 83617 (326.63 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/10
# 2084/2084 [==============================] - 13s 6ms/step - loss: 2.8565 - acc: 0.0758 - val_loss: 1.6178 - val_acc: 0.0000e+00
# Epoch 2/10
# 2084/2084 [==============================] - 11s 5ms/step - loss: 1.5690 - acc: 4.0000e-05 - val_loss: 1.5755 - val_acc: 0.0000e+00
# Epoch 3/10
# ...

# %%
import matplotlib.pyplot as plt

acc = history.history['acc']
val_acc = history.history['val_acc']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(acc) + 1)

plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()

plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %%
from keras.datasets import imdb
from keras import preprocessing

max_features = 10000
maxlen = 220

(x_train, y_train), (x_test, y_test) = imdb.load_data(num_words=max_features)

x_train = preprocessing.sequence.pad_sequences(x_train, maxlen=maxlen)
x_test  = preprocessing.sequence.pad_sequences(x_test, maxlen=maxlen)

# %%
# Using sigmoid, relu, and linear

from keras.models import Sequential
from keras.layers import Flatten, Dense, Embedding

model = Sequential()

num_layer = 16
model.add(Embedding(max_features, num_layer, input_length=maxlen))
model.add(Flatten())
model.add(Dense(1, activation='sigmoid'))
model.add(Dense(32, activation='relu'))
model.add(Dense(1, activation='linear'))
model.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['acc'])
model.summary()
history = model.fit(x_train, y_train, epochs=10, batch_size=12, validation_data=(x_test, y_test))
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  embedding_5 (Embedding)     (None, 220, 16)           160000
#
#  flatten_5 (Flatten)         (None, 3520)              0
#
#  dense_10 (Dense)            (None, 1)                 3521
#
#  dense_11 (Dense)            (None, 32)                64
#
#  dense_12 (Dense)            (None, 1)                 33
#
# ...
# Total params: 163618 (639.13 KB)
# Trainable params: 163618 (639.13 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/10
# 2084/2084 [==============================] - 12s 5ms/step - loss: 0.4639 - acc: 0.7957 - val_loss: 0.4147 - val_acc: 0.8711
# Epoch 2/10
# 2084/2084 [==============================] - 14s 7ms/step - loss: 0.3580 - acc: 0.9005 - val_loss: 0.4073 - val_acc: 0.8823
# Epoch 3/10
# ...

# %%
import matplotlib.pyplot as plt

acc = history.history['acc']
val_acc = history.history['val_acc']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(acc) + 1)

plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()

plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %%
from keras.datasets import imdb
from keras import preprocessing

max_features = 10000
maxlen = 260

(x_train, y_train), (x_test, y_test) = imdb.load_data(num_words=max_features)

x_train = preprocessing.sequence.pad_sequences(x_train, maxlen=maxlen)
x_test  = preprocessing.sequence.pad_sequences(x_test, maxlen=maxlen)

# %%
# Using sigmoid, Tanh, and linear

from keras.models import Sequential
from keras.layers import Flatten, Dense, Embedding

model = Sequential()

num_layer = 64
model.add(Embedding(max_features, num_layer, input_length=maxlen))
model.add(Flatten())
model.add(Dense(1, activation='sigmoid'))
model.add(Dense(64, activation='tanh'))
model.add(Dense(1, activation='linear'))
model.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['acc'])
model.summary()
history = model.fit(x_train, y_train, epochs=10, batch_size=12, validation_data=(x_test, y_test))
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  embedding_6 (Embedding)     (None, 260, 64)           640000
#
#  flatten_6 (Flatten)         (None, 16640)             0
#
#  dense_13 (Dense)            (None, 1)                 16641
#
#  dense_14 (Dense)            (None, 64)                128
#
#  dense_15 (Dense)            (None, 1)                 65
#
# ...
# Total params: 656834 (2.51 MB)
# Trainable params: 656834 (2.51 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/10
# 2084/2084 [==============================] - 18s 8ms/step - loss: 0.4757 - acc: 0.8048 - val_loss: 0.4117 - val_acc: 0.8760
# Epoch 2/10
# 2084/2084 [==============================] - 20s 10ms/step - loss: 0.3524 - acc: 0.9210 - val_loss: 0.7178 - val_acc: 0.8536
# Epoch 3/10
# ...

# %%
import matplotlib.pyplot as plt

acc = history.history['acc']
val_acc = history.history['val_acc']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(acc) + 1)

plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()

plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %%
# Examine 4 different activation functions (sigmoid, relu, tanh, one other choice of yours after research).
# Summarize which one performed the best (no need to explain the reasons for this problem).

# %%
# 1. Sigmoid

# %%
from keras.datasets import imdb
from keras import preprocessing

max_features = 10000
maxlen = 20

(x_train, y_train), (x_test, y_test) = imdb.load_data(num_words=max_features)

x_train = preprocessing.sequence.pad_sequences(x_train, maxlen=maxlen)
x_test  = preprocessing.sequence.pad_sequences(x_test, maxlen=maxlen)
# Out:
# ...
# 17464789/17464789 [==============================] - 1s 0us/step

# %%
from keras.models import Sequential
from keras.layers import Flatten, Dense, Embedding

model = Sequential()

num_layer = 8
model.add(Embedding(max_features, num_layer, input_length=maxlen))
model.add(Flatten())
model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['acc'])
model.summary()
history = model.fit(x_train, y_train, epochs=10, batch_size=12, validation_data=(x_test, y_test))
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  embedding (Embedding)       (None, 20, 8)             80000
#
#  flatten (Flatten)           (None, 160)               0
#
#  dense (Dense)               (None, 1)                 161
#
# ...
# Total params: 80161 (313.13 KB)
# Trainable params: 80161 (313.13 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/10
# 2084/2084 [==============================] - 24s 10ms/step - loss: 0.6247 - acc: 0.6545 - val_loss: 0.5333 - val_acc: 0.7363
# Epoch 2/10
# 2084/2084 [==============================] - 11s 5ms/step - loss: 0.4855 - acc: 0.7651 - val_loss: 0.4917 - val_acc: 0.7554
# Epoch 3/10
# 2084/2084 [==============================] - 10s 5ms/step - loss: 0.4436 - acc: 0.7926 - val_loss: 0.4872 - val_acc: 0.7634
# Epoch 4/10
# ...

# %%
import matplotlib.pyplot as plt

accSigmoid = history.history['acc']
val_accSigmoid = history.history['val_acc']
lossSigmoid = history.history['loss']
val_lossSigmoid = history.history['val_loss']

epochs = range(1, len(accSigmoid) + 1)

plt.plot(epochs, accSigmoid, 'bo', label='Training acc')
plt.plot(epochs, val_accSigmoid, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()

epochs = range(1, len(lossSigmoid) + 1)
plt.plot(epochs, lossSigmoid, 'bo', label='Training loss')
plt.plot(epochs, val_lossSigmoid, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %%
# 2. Relu

# %%
from keras.datasets import imdb
from keras import preprocessing

max_features = 10000
maxlen = 20

(x_train, y_train), (x_test, y_test) = imdb.load_data(num_words=max_features)

x_train = preprocessing.sequence.pad_sequences(x_train, maxlen=maxlen)
x_test  = preprocessing.sequence.pad_sequences(x_test, maxlen=maxlen)

# %%
from keras.models import Sequential
from keras.layers import Flatten, Dense, Embedding

model = Sequential()

num_layer = 8
model.add(Embedding(max_features, num_layer, input_length=maxlen))
model.add(Flatten())
model.add(Dense(1, activation='relu'))
model.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['acc'])
model.summary()
history = model.fit(x_train, y_train, epochs=10, batch_size=12, validation_data=(x_test, y_test))
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  embedding_1 (Embedding)     (None, 20, 8)             80000
#
#  flatten_1 (Flatten)         (None, 160)               0
#
#  dense_1 (Dense)             (None, 1)                 161
#
# ...
# Total params: 80161 (313.13 KB)
# Trainable params: 80161 (313.13 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/10
# 2084/2084 [==============================] - 12s 5ms/step - loss: 0.7179 - acc: 0.6762 - val_loss: 0.6074 - val_acc: 0.7445
# Epoch 2/10
# 2084/2084 [==============================] - 9s 4ms/step - loss: 0.5770 - acc: 0.7817 - val_loss: 0.6908 - val_acc: 0.7530
# Epoch 3/10
# 2084/2084 [==============================] - 7s 4ms/step - loss: 0.5679 - acc: 0.8058 - val_loss: 0.7642 - val_acc: 0.7514
# Epoch 4/10
# ...

# %%
import matplotlib.pyplot as plt

accRelu = history.history['acc']
val_accRelu = history.history['val_acc']
lossRelu = history.history['loss']
val_lossRelu = history.history['val_loss']

epochs = range(1, len(accRelu) + 1)

plt.plot(epochs, accRelu, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()

epochs = range(1, len(lossRelu) + 1)
plt.plot(epochs, lossRelu, 'bo', label='Training loss')
plt.plot(epochs, val_lossRelu, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %%
# Tanh

# %%
from keras.datasets import imdb
from keras import preprocessing

max_features = 10000
maxlen = 20

(x_train, y_train), (x_test, y_test) = imdb.load_data(num_words=max_features)

x_train = preprocessing.sequence.pad_sequences(x_train, maxlen=maxlen)
x_test  = preprocessing.sequence.pad_sequences(x_test, maxlen=maxlen)

# %%
from keras.models import Sequential
from keras.layers import Flatten, Dense, Embedding

model = Sequential()

num_layer = 8
model.add(Embedding(max_features, num_layer, input_length=maxlen))
model.add(Flatten())
model.add(Dense(1, activation='tanh'))
model.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['acc'])
model.summary()
history = model.fit(x_train, y_train, epochs=10, batch_size=12, validation_data=(x_test, y_test))
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  embedding_2 (Embedding)     (None, 20, 8)             80000
#
#  flatten_2 (Flatten)         (None, 160)               0
#
#  dense_2 (Dense)             (None, 1)                 161
#
# ...
# Total params: 80161 (313.13 KB)
# Trainable params: 80161 (313.13 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/10
# 2084/2084 [==============================] - 10s 5ms/step - loss: 0.7406 - acc: 0.6729 - val_loss: 0.6300 - val_acc: 0.7437
# Epoch 2/10
# 2084/2084 [==============================] - 7s 3ms/step - loss: 0.6019 - acc: 0.7723 - val_loss: 0.6820 - val_acc: 0.7540
# Epoch 3/10
# 2084/2084 [==============================] - 11s 5ms/step - loss: 0.6037 - acc: 0.7978 - val_loss: 0.7036 - val_acc: 0.7528
# Epoch 4/10
# ...

# %%
import matplotlib.pyplot as plt

accTanh = history.history['acc']
val_accTanh = history.history['val_acc']
lossTanh = history.history['loss']
val_lossTanh = history.history['val_loss']

epochs = range(1, len(accTanh) + 1)

plt.plot(epochs, accTanh, 'bo', label='Training acc')
plt.plot(epochs, val_accTanh, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()

epochs = range(1, len(lossTanh) + 1)
plt.plot(epochs, lossTanh, 'bo', label='Training loss')
plt.plot(epochs, val_lossTanh, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %%
# Linear

# %%
from keras.datasets import imdb
from keras import preprocessing

max_features = 10000
maxlen = 20

(x_train, y_train), (x_test, y_test) = imdb.load_data(num_words=max_features)

x_train = preprocessing.sequence.pad_sequences(x_train, maxlen=maxlen)
x_test  = preprocessing.sequence.pad_sequences(x_test, maxlen=maxlen)

# %%
from keras.models import Sequential
from keras.layers import Flatten, Dense, Embedding

model = Sequential()

num_layer = 8
model.add(Embedding(max_features, num_layer, input_length=maxlen))
model.add(Flatten())
model.add(Dense(1, activation='linear'))
model.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['acc'])
model.summary()
history = model.fit(x_train, y_train, epochs=10, batch_size=12, validation_data=(x_test, y_test))
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  embedding_3 (Embedding)     (None, 20, 8)             80000
#
#  flatten_3 (Flatten)         (None, 160)               0
#
#  dense_3 (Dense)             (None, 1)                 161
#
# ...
# Total params: 80161 (313.13 KB)
# Trainable params: 80161 (313.13 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/10
# 2084/2084 [==============================] - 8s 4ms/step - loss: 0.6917 - acc: 0.6807 - val_loss: 0.6368 - val_acc: 0.7487
# Epoch 2/10
# 2084/2084 [==============================] - 9s 4ms/step - loss: 0.5893 - acc: 0.7780 - val_loss: 0.6636 - val_acc: 0.7562
# Epoch 3/10
# 2084/2084 [==============================] - 9s 5ms/step - loss: 0.5712 - acc: 0.8032 - val_loss: 0.7392 - val_acc: 0.7557
# Epoch 4/10
# ...

# %%
import matplotlib.pyplot as plt

accLinear = history.history['acc']
val_accLinear = history.history['val_acc']
lossLinear = history.history['loss']
val_lossLinear = history.history['val_loss']

epochs = range(1, len(accLinear) + 1)

plt.plot(epochs, accLinear, 'bo', label='Training acc')
plt.plot(epochs, val_accLinear, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()

epochs = range(1, len(lossLinear) + 1)
plt.plot(epochs, lossLinear, 'bo', label='Training loss')
plt.plot(epochs, val_lossLinear, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %%
# Sigmoid, relu, tanh, and linear activation functions  graph

# %%
import matplotlib.pyplot as plt

accSigmoid = history.history['acc']
val_accSigmoid = history.history['val_acc']
lossSigmoid = history.history['loss']
val_lossSigmoid = history.history['val_loss']
epochs = range(1, len(accSigmoid) + 1)
plt.plot(epochs, accSigmoid, 'bo', label='Training acc')
plt.plot(epochs, val_accSigmoid, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()
plt.figure()
epochs = range(1, len(lossSigmoid) + 1)
plt.plot(epochs, lossSigmoid, 'bo', label='Training loss')
plt.plot(epochs, val_lossSigmoid, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()


accRelu = history.history['acc']
val_accRelu = history.history['val_acc']
lossRelu = history.history['loss']
val_lossRelu = history.history['val_loss']
epochs = range(1, len(accRelu) + 1)
plt.plot(epochs, acc, 'go', label='Training acc', color='green')
plt.plot(epochs, val_acc, 'g', label='Validation acc', color='green')
plt.title('Training and validation accuracy')
plt.legend()
plt.figure()
epochs = range(1, len(lossRelu) + 1)
plt.plot(epochs, lossRelu, 'go', label='Training loss', color='green')
plt.plot(epochs, val_lossRelu, 'g', label='Validation loss', color='green')
plt.title('Training and validation loss')
plt.legend()



accTanh = history.history['acc']
val_accTanh = history.history['val_acc']
lossTanh = history.history['loss']
val_lossTanh = history.history['val_loss']
epochs = range(1, len(accTanh) + 1)
plt.plot(epochs, accTanh, 'bo', label='Training acc', color='red')
plt.plot(epochs, val_accTanh, 'b', label='Validation acc', color='red')
plt.title('Training and validation accuracy')
plt.legend()
plt.figure()
epochs = range(1, len(lossTanh) + 1)
plt.plot(epochs, lossTanh, 'bo', label='Training loss', color='red')
plt.plot(epochs, val_lossTanh, 'b', label='Validation loss', color='red')
plt.title('Training and validation loss')
plt.legend()


accLinear = history.history['acc']
val_accLinear = history.history['val_acc']
lossLinear = history.history['loss']
val_lossLinear = history.history['val_loss']
epochs = range(1, len(accLinear) + 1)
plt.plot(epochs, accLinear, 'bo', label='Training acc', color='purple')
plt.plot(epochs, val_accLinear, 'b', label='Validation acc', color='purple')
plt.title('Training and validation accuracy')
plt.legend()
plt.figure()
epochs = range(1, len(lossLinear) + 1)
plt.plot(epochs, lossLinear, 'bo', label='Training loss', color='purple')
plt.plot(epochs, val_lossLinear, 'b', label='Validation loss', color='purple')
plt.title('Training and validation loss')
plt.legend()



plt.show()
# Out:
# <ipython-input-17-b98bafcb9778>:25: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "go" (-> color='g'). The keyword argument will take precedence.
#   plt.plot(epochs, acc, 'go', label='Training acc', color='green')
# <ipython-input-17-b98bafcb9778>:26: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "g" (-> color=(0.0, 0.5, 0.0, 1)). The keyword argument will take precedence.
#   plt.plot(epochs, val_acc, 'g', label='Validation acc', color='green')
# <ipython-input-17-b98bafcb9778>:31: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "go" (-> color='g'). The keyword argument will take precedence.
#   plt.plot(epochs, lossRelu, 'go', label='Training loss', color='green')
# ...

# %%
# Sigmoid, relu, tanh, and linear activation functions  graph

# %%
from keras.datasets import imdb
from keras import preprocessing

max_features = 10000
maxlen = 20

(x_train, y_train), (x_test, y_test) = imdb.load_data(num_words=max_features)

x_train = preprocessing.sequence.pad_sequences(x_train, maxlen=maxlen)
x_test  = preprocessing.sequence.pad_sequences(x_test, maxlen=maxlen)

# %%
from keras.models import Sequential
from keras.layers import Flatten, Dense, Embedding

model = Sequential()

num_layer = 8
model.add(Embedding(max_features, num_layer, input_length=maxlen))
model.add(Flatten())
model.add(Dense(1, activation='sigmoid'))
model.add(Dense(1, activation='relu'))
model.add(Dense(1, activation='tanh'))
model.add(Dense(1, activation='linear'))
model.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['acc'])
model.summary()
history = model.fit(x_train, y_train, epochs=10, batch_size=12, validation_data=(x_test, y_test))
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  embedding_4 (Embedding)     (None, 20, 8)             80000
#
#  flatten_4 (Flatten)         (None, 160)               0
#
#  dense_4 (Dense)             (None, 1)                 161
#
#  dense_5 (Dense)             (None, 1)                 2
#
#  dense_6 (Dense)             (None, 1)                 2
#
#  dense_7 (Dense)             (None, 1)                 2
#
# ...
# Total params: 80167 (313.15 KB)
# Trainable params: 80167 (313.15 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/10
# 2084/2084 [==============================] - 9s 4ms/step - loss: 7.7125 - acc: 0.5000 - val_loss: 7.7125 - val_acc: 0.5000
# Epoch 2/10
# 2084/2084 [==============================] - 9s 4ms/step - loss: 7.7125 - acc: 0.5000 - val_loss: 7.7125 - val_acc: 0.5000
# Epoch 3/10
# ...

# %%
import matplotlib.pyplot as plt

acc = history.history['acc']
val_acc = history.history['val_acc']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(acc) + 1)

plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()

plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()
